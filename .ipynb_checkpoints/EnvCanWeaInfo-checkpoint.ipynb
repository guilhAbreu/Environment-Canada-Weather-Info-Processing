# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ipyleaflet import *

# %%
method       = 'hourly'
dataPath     = "../data_set/EnviromentCanada/QuebecStations/"+method+"/"
metaDataName = "stations_inventory.csv"

# %% [markdown]
# # Environment Canada Weather Information

# %% [markdown]
# ## Province of Quebec Information
#
# In this section, it's computed relevant information about the hourly data from the Province of Quebec. In order to begin our analysis, let us focus our attention on a short space of time. Therefore, we are going to be interested in the period between June 1st and August 31st. The most relevant measurements we are concern about are Air Temperature, Relative Humidity, and Dew Point Temperature. So, most treatments done here are concern about them as well.

# %%
#It opens the metadata and selects the Ids of the Province of Quebec with hourly data at least untill 2018.
metaData = pd.read_csv(metaDataName)
quebecStations = metaData[(metaData["Province"] == "QUEBEC") & (metaData["HLY Last Year"] >= 2018)]
IDs = quebecStations["Station ID"].unique()

# %%
dataSet = dict()

#It opens them
for ID in IDs:
    data = pd.read_csv(dataPath+str(ID)+'.csv')
    data = data.dropna(axis = 0, how = 'all')
    dataSet[str(ID)] = data

# %% [markdown]
# ### Missing Data
#
# Missing data is one of the most relevant information we must know about the data. As it was mentioned above, we are concern about Air Temperature, Relative Humidity, and Dew Point Temperature. So, here it's computed how many stations don't have these measurements in the period of interest.

# %%
#It computes how many relevant data are missing on the dataset
countTemp = countRH = countDP   = 0
missingData = pd.DataFrame([], columns = ['Station ID', 'Station Name', 'Has Temp', 
                                          'Has RH', 'Has DP', 'lat', 'lng'])
missingData['Station ID']   = (quebecStations['Station ID'].values).astype('str')
missingData['Station Name'] = quebecStations['Name'].values
missingData['lat']          = np.asarray(quebecStations['Latitude (Decimal Degrees)'].values)
missingData['lng']          = np.asarray(quebecStations['Longitude (Decimal Degrees)'].values)
for key in dataSet:
    data = dataSet[key]
    
    noTmp = data['Temp (°C)'].isna().all()
    noRH  = data['Rel Hum (%)'].isna().all()
    noDP  = data['Dew Point Temp (°C)'].isna().all()
    
    countTemp += int(noTmp)
    countRH   += int(noRH)
    countDP   += int(noDP)
    
    missingData.loc[missingData['Station ID'] == key,'Has Temp'] = not noTmp
    missingData.loc[missingData['Station ID'] == key,'Has RH']   = not noRH
    missingData.loc[missingData['Station ID'] == key,'Has DP']   = not noDP

# %% [markdown]
# ### All Stations Available in 2018

# %%
from IPython.display import display, HTML
display(HTML(missingData.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Station ID</th>
#       <th>Station Name</th>
#       <th>Has Temp</th>
#       <th>Has RH</th>
#       <th>Has DP</th>
#       <th>lat</th>
#       <th>lng</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>27803</td>
#       <td>BEAUPORT</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>46.84</td>
#       <td>-71.20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>27325</td>
#       <td>DESCHAMBAULT</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.69</td>
#       <td>-71.97</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8989</td>
#       <td>ILE D'ORLEANS</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>47.00</td>
#       <td>-70.81</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5237</td>
#       <td>L'ASSOMPTION</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.81</td>
#       <td>-73.43</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10871</td>
#       <td>L'ETAPE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>47.56</td>
#       <td>-71.23</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>51457</td>
#       <td>QUEBEC INTL A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.79</td>
#       <td>-71.39</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>27646</td>
#       <td>SHAWINIGAN</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.56</td>
#       <td>-72.73</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>51698</td>
#       <td>TROIS RIVIERES A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.35</td>
#       <td>-72.68</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>10764</td>
#       <td>TROIS-RIVIERES</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.35</td>
#       <td>-72.52</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>8321</td>
#       <td>TROIS-RIVIERES</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.37</td>
#       <td>-72.68</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>29452</td>
#       <td>VALCARTIER A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.90</td>
#       <td>-71.50</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>5293</td>
#       <td>VALCARTIER A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.90</td>
#       <td>-71.50</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>10247</td>
#       <td>ILE AUX GRUES</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>47.07</td>
#       <td>-70.53</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>10975</td>
#       <td>LAC SAINT-PIERRE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.18</td>
#       <td>-72.92</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>27377</td>
#       <td>STE-FOY (U. LAVAL)</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.78</td>
#       <td>-71.29</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>29714</td>
#       <td>LEMIEUX</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.30</td>
#       <td>-72.06</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>26892</td>
#       <td>QUEBEC/JEAN LESAGE INTL</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.80</td>
#       <td>-71.38</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>10815</td>
#       <td>FRELIGHSBURG</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.03</td>
#       <td>-72.85</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>42013</td>
#       <td>GRANBY</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.37</td>
#       <td>-72.77</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>51638</td>
#       <td>LAC MEGANTIC</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.60</td>
#       <td>-70.88</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>54938</td>
#       <td>NANTES</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>45.61</td>
#       <td>-70.93</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>5397</td>
#       <td>LENNOXVILLE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.37</td>
#       <td>-71.82</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>10761</td>
#       <td>MCTAVISH</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.50</td>
#       <td>-73.58</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>47888</td>
#       <td>MOBILE UPPER AIR STATION-QUEBEC</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>45.43</td>
#       <td>-73.93</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>51157</td>
#       <td>MONTREAL INTL A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.47</td>
#       <td>-73.74</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>10732</td>
#       <td>NICOLET</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.23</td>
#       <td>-72.66</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>10762</td>
#       <td>STE-CLOTILDE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.17</td>
#       <td>-73.68</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>48374</td>
#       <td>MONTREAL/ST-HUBERT</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.52</td>
#       <td>-73.42</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>47587</td>
#       <td>SAINT-GERMAIN-DE-GRANTHAM</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.83</td>
#       <td>-72.54</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>48371</td>
#       <td>SHERBROOKE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.44</td>
#       <td>-71.69</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>45309</td>
#       <td>THETFORD MINES RCS</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.05</td>
#       <td>-71.27</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>26777</td>
#       <td>BEAUCEVILLE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>46.21</td>
#       <td>-70.79</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>10801</td>
#       <td>LAC MEMPHREMAGOG</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.27</td>
#       <td>-72.17</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>10873</td>
#       <td>STE-ANNE-DE-BELLEVUE 1</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.43</td>
#       <td>-73.93</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>10982</td>
#       <td>ST-ANICET 1</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.12</td>
#       <td>-74.29</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>10843</td>
#       <td>L'ACADIE</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.29</td>
#       <td>-73.35</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>30165</td>
#       <td>MONTREAL/PIERRE ELLIOTT TRUDEAU INTL</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.47</td>
#       <td>-73.74</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>50719</td>
#       <td>OTTAWA GATINEAU A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.52</td>
#       <td>-75.56</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>53001</td>
#       <td>OTTAWA GATINEAU A</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.52</td>
#       <td>-75.56</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>27717</td>
#       <td>HIGH FALLS</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>45.84</td>
#       <td>-75.65</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>5606</td>
#       <td>MANIWAKI AIRPO

# %%
def countData(dataFrame, dictionary, column, dataQuantity):
    '''
    Description: It calculate the pecentage of data available  
    '''
    dataSet = dictionary.copy()
    newdf = dataFrame.copy()
    for station in dataSet:
        data = dataSet[station]
        newdf.loc[newdf['Station ID'] == station, "Data Available "+column] = round(100*data[column].count()/dataQuantity,2)
    return newdf

# %%
def fltrbyDQ(dictionary, column, dataQuantity, threshold = 0.6):
    '''
    Description: Filter by Data Quantity. It returns a list with keys that don't have enough data according to the threshold passed.
    '''
    dataSet = dictionary.copy()
    statList = list()
    for station in dataSet:
        data = dataSet[station]
        if data[column].count()/dataQuantity < threshold:
            statList.append(station)
    return statList

# %%
def removeItems(dictionary, keys):
    '''
    Description: Remove a list of keys from a dict object.
    '''
    d = dictionary.copy()
    for key in keys:
        d.pop(key)
    return d

# %%
dataLength = len(dataSet)
print('Missing Data in %d stations:' %dataLength)
print('Air Temperature:     %.2f'  %(100*countTemp/dataLength) + '%')
print('Relative Humidity:   %.2f'  %(100*countRH/dataLength) + '%')
print('Dew Point:           %.2f'  %(100*countDP/dataLength) + '%')
# Out:
# Missing Data in 159 stations:
# Air Temperature:     11.32%
# Relative Humidity:   13.84%
# Dew Point:           13.84%

# %% [markdown]
# ### Stations that have hourly data from 06/01/2018 to 31/08/2018

# %%
availableStations = missingData[(missingData['Has Temp'] == True) & (missingData['Has RH'] == True) & (missingData['Has DP'] == True)]
availableStations.sort_index(axis='index')
availableStations = availableStations.reset_index(drop=True)
availableStations = availableStations[['Station ID', 'Station Name', 'lat', 'lng']]

# %%
# clean up dataSet, remainning just the stations that  
avs    = availableStations['Station ID'].values
nodata = np.setdiff1d(missingData['Station ID'].values, avs)
dataSet = removeItems(dataSet, nodata)

# %%
from datetime import date

delta = date(2018, 8, 31) - date(2018, 6, 1)
removeList = fltrbyDQ(dataSet, 'Temp (°C)', (delta.days + 1)*24, threshold=0.9)
t90 = removeItems(dataSet,removeList)
removeList = fltrbyDQ(dataSet, 'Rel Hum (%)', (delta.days + 1)*24, threshold=0.9)
rh90 = removeItems(dataSet,removeList)
removeList = fltrbyDQ(dataSet, 'Dew Point Temp (°C)', (delta.days + 1)*24, threshold=0.9)
dp90 = removeItems(dataSet,removeList)

# %%
availableStations = countData(availableStations, dataSet, 'Temp (°C)', (delta.days + 1)*24)
availableStations = countData(availableStations, dataSet, 'Rel Hum (%)', (delta.days + 1)*24)
availableStations = countData(availableStations, dataSet, 'Dew Point Temp (°C)', (delta.days + 1)*24)
display(HTML(availableStations.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Station ID</th>
#       <th>Station Name</th>
#       <th>lat</th>
#       <th>lng</th>
#       <th>Data Available Temp (°C)</th>
#       <th>Data Available Rel Hum (%)</th>
#       <th>Data Available Dew Point Temp (°C)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>27325</td>
#       <td>DESCHAMBAULT</td>
#       <td>46.69</td>
#       <td>-71.97</td>
#       <td>99.95</td>
#       <td>99.95</td>
#       <td>99.95</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5237</td>
#       <td>L'ASSOMPTION</td>
#       <td>45.81</td>
#       <td>-73.43</td>
#       <td>100.00</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10871</td>
#       <td>L'ETAPE</td>
#       <td>47.56</td>
#       <td>-71.23</td>
#       <td>96.65</td>
#       <td>96.38</td>
#       <td>96.38</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>51457</td>
#       <td>QUEBEC INTL A</td>
#       <td>46.79</td>
#       <td>-71.39</td>
#       <td>99.91</td>
#       <td>99.86</td>
#       <td>99.86</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>27646</td>
#       <td>SHAWINIGAN</td>
#       <td>46.56</td>
#       <td>-72.73</td>
#       <td>99.95</td>
#       <td>99.95</td>
#       <td>99.95</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>51698</td>
#       <td>TROIS RIVIERES A</td>
#       <td>46.35</td>
#       <td>-72.68</td>
#       <td>92.75</td>
#       <td>92.75</td>
#       <td>92.75</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>10764</td>
#       <td>TROIS-RIVIERES</td>
#       <td>46.35</td>
#       <td>-72.52</td>
#       <td>99.91</td>
#       <td>99.91</td>
#       <td>99.91</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8321</td>
#       <td>TROIS-RIVIERES</td>
#       <td>46.37</td>
#       <td>-72.68</td>
#       <td>99.64</td>
#       <td>99.64</td>
#       <td>99.64</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>29452</td>
#       <td>VALCARTIER A</td>
#       <td>46.90</td>
#       <td>-71.50</td>
#       <td>98.51</td>
#       <td>98.41</td>
#       <td>98.41</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5293</td>
#       <td>VALCARTIER A</td>
#       <td>46.90</td>
#       <td>-71.50</td>
#       <td>28.99</td>
#       <td>28.99</td>
#       <td>28.99</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10975</td>
#       <td>LAC SAINT-PIERRE</td>
#       <td>46.18</td>
#       <td>-72.92</td>
#       <td>99.77</td>
#       <td>99.77</td>
#       <td>99.77</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>27377</td>
#       <td>STE-FOY (U. LAVAL)</td>
#       <td>46.78</td>
#       <td>-71.29</td>
#       <td>99.86</td>
#       <td>58.33</td>
#       <td>58.33</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>29714</td>
#       <td>LEMIEUX</td>
#       <td>46.30</td>
#       <td>-72.06</td>
#       <td>98.55</td>
#       <td>98.55</td>
#       <td>98.55</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>26892</td>
#       <td>QUEBEC/JEAN LESAGE INTL</td>
#       <td>46.80</td>
#       <td>-71.38</td>
#       <td>99.95</td>
#       <td>99.95</td>
#       <td>99.95</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>10815</td>
#       <td>FRELIGHSBURG</td>
#       <td>45.03</td>
#       <td>-72.85</td>
#       <td>95.79</td>
#       <td>95.79</td>
#       <td>95.79</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>42013</td>
#       <td>GRANBY</td>
#       <td>45.37</td>
#       <td>-72.77</td>
#       <td>99.32</td>
#       <td>99.32</td>
#       <td>99.32</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>51638</td>
#       <td>LAC MEGANTIC</td>
#       <td>45.60</td>
#       <td>-70.88</td>
#       <td>99.77</td>
#       <td>99.77</td>
#       <td>99.77</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>5397</td>
#       <td>LENNOXVILLE</td>
#       <td>45.37</td>
#       <td>-71.82</td>
#       <td>99.59</td>
#       <td>99.59</td>
#       <td>99.59</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>10761</td>
#       <td>MCTAVISH</td>
#       <td>45.50</td>
#       <td>-73.58</td>
#       <td>99.68</td>
#       <td>99.68</td>
#       <td>99.68</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>51157</td>
#       <td>MONTREAL INTL A</td>
#       <td>45.47</td>
#       <td>-73.74</td>
#       <td>99.91</td>
#       <td>99.91</td>
#       <td>99.91</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>10732</td>
#       <td>NICOLET</td>
#       <td>46.23</td>
#       <td>-72.66</td>
#       <td>99.77</td>
#       <td>99.77</td>
#       <td>99.77</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>10762</td>
#       <td>STE-CLOTILDE</td>
#       <td>45.17</td>
#       <td>-73.68</td>
#       <td>98.96</td>
#       <td>98.96</td>
#       <td>98.96</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>48374</td>
#       <td>MONTREAL/ST-HUBERT</td>
#       <td>45.52</td>
#       <td>-73.42</td>
#       <td>99.91</td>
#       <td>99.91</td>
#       <td>99.91</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>47587</td>
#       <td>SAINT-GERMAIN-DE-GRANTHAM</td>
#       <td>45.83</td>
#       <td>-72.54</td>
#       <td>91.12</td>
#       <td>91.12</td>
#       <td>91.12</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>48371</td>
#       <td>SHERBROOKE</td>
#       <td>45.44</td>
#       <td>-71.69</td>
#       <td>99.91</td>
#       <td>99.91</td>
#       <td>99.91</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>45309</td>
#       <td>THETFORD MINES RCS</td>
#       <td>46.05</td>
#       <td>-71.27</td>
#       <td>100.00</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>26777</td>
#       <td>BEAUCEVILLE</td>
#       <td>46.21</td>
#       <td>-70.79</td>
#       <td>100.00</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>10801</td>
#       <td>LAC MEMPHREMAGOG</td>
#       <td>45.27</td>
#       <td>-72.17</td>
#       <td>99.77</td>
#       <td>99.77</td>
#       <td>99.77</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>10873</td>
#       <td>STE-ANNE-DE-BELLEVUE 1</td>
#       <td>45.43</td>
#       <td>-73.93</td>
#       <td>98.01</td>
#       <td>98.01</td>
#       <td>98.01</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>10982</td>
#       <td>ST-ANICET 1</td>
#       <td>45.12</td>
#       <td>-74.29</td>
#       <td>100.00</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>10843</td>
#       <td>L'ACADIE</td>
#       <td>45.29</td>
#       <td>-73.35</td>
#       <td>99.95</td>
#       <td>99.95</td>
#       <td>99.95</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>30165</td>
#       <td>MONTREAL/PIERRE ELLIOTT TRUDEAU INTL</td>
#       <td>45.47</td>
#       <td>-73.74</td>
#       <td>99.91</td>
#       <td>99.91</td>
#       <td>99.91</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>50719</td>
#       <td>OTTAWA GATINEAU A</td>
#       <td>45.52</td>
#       <td>-75.56</td>
#       <td>62.45</td>
#       <td>62.45</td>
#       <td>62.45</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>53001</td>
#       <td>OTTAWA GATINEAU A</td>
#       <td>45.52</td>
#       <td>-75.56</td>
#       <td>99.82</td>
#       <td>99.82</td>
#       <td>99.82</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>27717</td>
#       <td>HIGH FALLS</td>
#       <td>45.84</td>
#       <td>-75.65</td>
#       <td>100.00</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>5606</td>
#       <td>MANIWAKI AIRPORT</td>
#       <td>46.27</td>
#       <td>-75.99</td>
#       <td>91.30</td>
#       <td>91.30</td>
#       <td>91.30</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>49608</td>
#       <td>MONTREAL MIRABEL INTL A</td>
#       <td>45.68</td>
#       <td>-74.04</td>
#       <td>99.95</td>
#       <td>99.95</td>
#       <td>99.95</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>10868</td>
#       <td>ST-JOVITE</td>
#       <td>46.08</td>
#       <td>-74.56</td>
#       <td>100.00</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>30173</td>
#       <td>BAIE-COMEAU A</td>
#       <td>49.13</td>
#       <td>-68.20</td>
#       <td>99.55</td>
#       <td>99.55</td>
#       <td>99.55</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>48968</td>
#       <td>BAIE-COMEAU</td>

# %%
print("%.2f" %(100*len(t90)/len(dataSet))+"%", end = ' ') 
print("of the Stations that provide hourly information has at least 90% of the Temperature information")
print("%.2f" %(100*len(rh90)/len(dataSet))+"%", end = ' ') 
print("of the Stations that provide hourly information has at least 90% of the Relative Humidty information")
print("%.2f" %(100*len(dp90)/len(dataSet))+"%", end = ' ') 
print("of the Stations that provide hourly information has at least 90% of the Dew Point Temperaturte information")
# Out:
# 83.21% of the Stations that provide hourly information has at least 90% of the Temperature information
# 80.29% of the Stations that provide hourly information has at least 90% of the Relative Humidty information
# 78.83% of the Stations that provide hourly information has at least 90% of the Dew Point Temperaturte information

# %% [markdown]
# ### Stations Map

# %%
from ipywidgets import HTML

m = Map(center=(53.402689, -70.424010), scroll_wheel_zoom = True,  zoom=4, basemap=basemaps.Esri.WorldStreetMap)
markers = list()
for index, row in availableStations.iterrows():
    location = (row['lat'],row['lng'])
    marker = Marker(location=location, draggable = False)
    msg = HTML()
    msg.value = 'Station: %s; ID: %s; Data Available of Temp: %.2f' %(row['Station Name'],
                                                                    row['Station ID'],
                                                                    row['Data Available Temp (°C)']) + '%; '
    msg.value += 'Data Available of RH: %.2f' %row['Data Available Rel Hum (%)'] + '%; '
    msg.value +='Data Available of DP: %.2f.' %row['Data Available Dew Point Temp (°C)'] + '%; '
    
    marker.popup = msg
    markers.append(marker)
    
marker_cluster = MarkerCluster(markers=markers)
m.add_layer(marker_cluster)

# %%
# mouse interaction handling

from ipywidgets import Label

label = Label()

def handle_interaction(**kwargs):
    if kwargs.get('type') == 'mousemove':
        label.value = str(kwargs.get('coordinates'))

# %% [markdown]
# **Here, we have a map with all stations available.**

# %%
m.on_interaction(handle_interaction)
display(m)
display(label)
# Out:
# Map(basemap={'url': 'http://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{…
# Label(value='')

# %%
from ipywidgets import HTML

stations90 = availableStations[(availableStations['Data Available Temp (°C)'] >= 90) 
                               & (availableStations['Data Available Rel Hum (%)'] >= 90) 
                               & (availableStations['Data Available Dew Point Temp (°C)'] >= 90)]
m2 = Map(center=(53.402689, -70.424010), scroll_wheel_zoom = True,  zoom=4, basemap=basemaps.Esri.WorldStreetMap)
markers = list()
for index, row in stations90.iterrows():
    location = (row['lat'],row['lng'])
    marker = Marker(location=location, draggable = False)
    msg = HTML()
    msg.value = 'Station: %s; ID: %s; Data Available of Temp: %.2f' %(row['Station Name'],
                                                                    row['Station ID'],
                                                                    row['Data Available Temp (°C)']) + '%; '
    msg.value += 'Data Available of RH: %.2f' %row['Data Available Rel Hum (%)'] + '%; '
    msg.value +='Data Available of DP: %.2f.' %row['Data Available Dew Point Temp (°C)'] + '%; '
    
    marker.popup = msg
    markers.append(marker)
    
marker_cluster = MarkerCluster(markers=markers)
m2.add_layer(marker_cluster)

# %% [markdown]
# **Here, we have a map with all stations available that have at least 90% of the hourly data.**

# %%
m2.on_interaction(handle_interaction)
display(m2)
display(label)
# Out:
# Map(basemap={'url': 'http://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{…
# Label(value='[61.17503266354878, -31.70406211845661]')

# %% [markdown]
# ### Temperature Histogram and Boxplot

# %%
tmp = np.asarray([dataSet[key]['Temp (°C)'].values for key in dataSet]).flatten()
tmp = tmp[~np.isnan(tmp)]

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig, ax = plt.subplots(1, 2, figsize =(16,4))

ax[0].set_title('Temperature Histogram')
ax[0].hist(tmp, bins=15)
ax[0].set(xlabel='Temperature (°C)', ylabel='Counts')

ax[1].set_title('Temperature Boxplot')
ax[1].boxplot(tmp, vert = False, flierprops=green_diamond)
_ = ax[1].set(xlabel='Temperature (°C)')

# %% [markdown]
# ### Relative Humidity Histogram and Boxplot

# %%
rh = np.asarray([dataSet[key]['Rel Hum (%)'].values for key in dataSet]).flatten()
rh = rh[~np.isnan(rh)]

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

fig, ax = plt.subplots(1, 2, figsize =(16,4))

ax[0].set_title('Relative Humidity Histogram')
ax[0].hist(rh, bins=20)
ax[0].set(xlabel='Relative Humidity (%)', ylabel='Counts')

ax[1].set_title('Relative Humidity Boxplot')
ax[1].boxplot(rh, vert = False, flierprops=green_diamond)
_ = ax[1].set(xlabel='Relative Humidity (%)')
